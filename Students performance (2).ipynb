# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sd=pd.read_excel('StudentsPerformance1.xlsx')
sd
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch  Column  Column.1 test preparation course  math score  \
# 0         standard     NaN       NaN                    none        72.0
# 1         standard     NaN       NaN               completed        69.0
# 2         standard     NaN       NaN                    none        90.0
# 3     free/reduced     NaN       NaN                    none        47.0
# 4         standard     NaN       NaN                    none        76.0
# ...            ...     ...       ...                     ...         ...
# 1000      standard     NaN       NaN               completed        88.0
# 1001  free/reduced     NaN       NaN                    none        62.0
# 1002  free/reduced     NaN       NaN               completed        59.0
# 1003      standard     NaN       NaN               completed        68.0
# 1004  free/reduced     NaN       NaN                    none        77.0
#
#       reading score  writing score
# 0              72.0           74.0
# 1              90.0           88.0
# 2              95.0           93.0
# 3              57.0           44.0
# 4              78.0           75.0
# ...             ...            ...
# 1000           99.0           95.0
# 1001           55.0           55.0
# 1002           71.0           65.0
# 1003           78.0           77.0
# 1004           86.0           86.0
#
# [1005 rows x 11 columns]

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student ID                   1005 non-null   int64
#  1   gender                       1005 non-null   object
#  2   race/ethnicity               1005 non-null   object
#  3   parental level of education  1005 non-null   object
#  4   lunch                        1005 non-null   object
#  5   Column                       0 non-null      float64
#  6   Column.1                     0 non-null      float64
#  7   test preparation course      1005 non-null   object
#  8   math score                   1000 non-null   float64
#  9   reading score                1000 non-null   float64
#  10  writing score                1000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.5+ KB

# %%
sd1=sd.copy()

# %%
sd1.isna().sum()
# Out:
# Student ID                     0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     5
# reading score                  5
# writing score                  5
# Total Score                    5
# Percentage                     5
# Status                         0
# dtype: int64

# %%
sd1['Total Score']=sd1['math score']+sd1['reading score']+sd1['writing score']
sd1
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch  Column  Column.1 test preparation course  math score  \
# 0         standard     NaN       NaN                    none        72.0
# 1         standard     NaN       NaN               completed        69.0
# 2         standard     NaN       NaN                    none        90.0
# 3     free/reduced     NaN       NaN                    none        47.0
# 4         standard     NaN       NaN                    none        76.0
# ...            ...     ...       ...                     ...         ...
# 1000      standard     NaN       NaN               completed        88.0
# 1001  free/reduced     NaN       NaN                    none        62.0
# 1002  free/reduced     NaN       NaN               completed        59.0
# 1003      standard     NaN       NaN               completed        68.0
# 1004  free/reduced     NaN       NaN                    none        77.0
#
#       reading score  writing score  Total Score
# 0              72.0           74.0        218.0
# 1              90.0           88.0        247.0
# 2              95.0           93.0        278.0
# 3              57.0           44.0        148.0
# 4              78.0           75.0        229.0
# ...             ...            ...          ...
# 1000           99.0           95.0        282.0
# 1001           55.0           55.0        172.0
# 1002           71.0           65.0        195.0
# 1003           78.0           77.0        223.0
# 1004           86.0           86.0        249.0
#
# [1005 rows x 12 columns]

# %%
sd1.drop(['Column','Column.1'],axis=1,inplace=True)
sd1
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# 1         standard               completed        69.0           90.0
# 2         standard                    none        90.0           95.0
# 3     free/reduced                    none        47.0           57.0
# 4         standard                    none        76.0           78.0
# ...            ...                     ...         ...            ...
# 1000      standard               completed        88.0           99.0
# 1001  free/reduced                    none        62.0           55.0
# 1002  free/reduced               completed        59.0           71.0
# 1003      standard               completed        68.0           78.0
# 1004  free/reduced                    none        77.0           86.0
#
#       writing score  Total Score
# 0              74.0        218.0
# 1              88.0        247.0
# 2              93.0        278.0
# 3              44.0        148.0
# 4              75.0        229.0
# ...             ...          ...
# 1000           95.0        282.0
# 1001           55.0        172.0
# 1002           65.0        195.0
# 1003           77.0        223.0
# 1004           86.0        249.0
#
# [1005 rows x 10 columns]

# %%
# 1).check whether null values are present in the given data.
sd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student ID                   1005 non-null   int64
#  1   gender                       1005 non-null   object
#  2   race/ethnicity               1005 non-null   object
#  3   parental level of education  1005 non-null   object
#  4   lunch                        1005 non-null   object
#  5   test preparation course      1005 non-null   object
#  6   math score                   1000 non-null   float64
#  7   reading score                1000 non-null   float64
#  8   writing score                1000 non-null   float64
#  9   Total Score                  1000 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 78.6+ KB

# %%
#sd.isna().sum()
sd1.median() # mean()
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\2039403970.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sd1.median()
# Student ID       503.0
# math score        66.0
# reading score     70.0
# writing score     69.0
# Total Score      205.0
# dtype: float64

# %%
#sd=sd.fillna().mean() # replace with median
#sd.head(3)
sd1.median()
sd2=sd1.fillna(sd.median())
sd2
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\885568831.py:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sd1.median()
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\885568831.py:4: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sd2=sd1.fillna(sd.median())
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# 1         standard               completed        69.0           90.0
# 2         standard                    none        90.0           95.0
# 3     free/reduced                    none        47.0           57.0
# 4         standard                    none        76.0           78.0
# ...            ...                     ...         ...            ...
# 1000      standard               completed        88.0           99.0
# 1001  free/reduced                    none        62.0           55.0
# 1002  free/reduced               completed        59.0           71.0
# 1003      standard               completed        68.0           78.0
# 1004  free/reduced                    none        77.0           86.0
#
#       writing score  Total Score
# 0              74.0        218.0
# 1              88.0        247.0
# 2              93.0        278.0
# 3              44.0        148.0
# 4              75.0        229.0
# ...             ...          ...
# 1000           95.0        282.0
# 1001           55.0        172.0
# 1002           65.0        195.0
# 1003           77.0        223.0
# 1004           86.0        249.0
#
# [1005 rows x 10 columns]

# %%
sd1.isna().sum()
# Out:
# Student ID                     0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     5
# reading score                  5
# writing score                  5
# Total Score                    5
# dtype: int64

# %%
#2.find the total number of students.
sd1['Student ID'].value_counts().sum()
# Out:
# 1005

# %%
#3.find the average for reading score.
sd1['reading score'].mean()
# Out:
# 69.169

# %%
#4.check the descriptive statistics for writing score.
sd1.describe()['writing score']
# Out:
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64

# %%
#5.find how many students had completed the test preparation.
sd1['test preparation course'].value_counts()
# Out:
# none         644
# completed    361
# Name: test preparation course, dtype: int64

# %%
#6.find the min score in math.
sd1['math score'].min()
# Out:
# 0.0

# %%
#7.find the max score in writing.
sd1['writing score'].max()
# Out:
# 100.0

# %%
#8.find the number of students by lunch.
sd1.groupby('lunch').count()['Student ID']
# Out:
# lunch
# free/reduced    356
# standard        649
# Name: Student ID, dtype: int64

# %%
sd1['math score'].sum()
# Out:
# 66089.0

# %%
sd1['reading score'].sum()
# Out:
# 69169.0

# %%
sd1['writing score'].sum()
# Out:
# 68054.0

# %%
#9.find the average score for each by race/ethnicity.
#average_list=[66089.0,69169.0,68054.0]
#sd1.groupby('race/ethnicity').mean(average_list)
#sd.drop('Column',axis=1,inplace=True)

#sd

# %%
#9.find the average score for each by race/ethnicity.
sd1.groupby('race/ethnicity').mean()['Total Score']
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\2399675795.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd1.groupby('race/ethnicity').mean()['Total Score']
# race/ethnicity
# group A    188.977528
# group B    196.405263
# group C    201.394984
# group D    207.538168
# group E    218.257143
# Name: Total Score, dtype: float64

# %%
#10.create a count plot for parental level of education.
#sns.countplot(x='parental level of education',sd1=sd1)
#sd1
#sd1['parental level of education'].value_counts().plot(kind='bar')
##sd1

sd1['parental level of education'].value_counts(normalize= True)
sd1['parental level of education'].value_counts(dropna= False).plot.bar(color='green')# ['orange','green','blue','yellow','red'])
plt.title('Comparison of parental level of education')
plt.xlabel('parental level of education')
plt.ylabel('Count')
plt.show()

# %%
#11. Find the total score of each student
#total_list=[66089.0,69169.0,68054.0]
#sd.groupby('Student ID').sum(total_list)
#sd.drop('Column',axis=1,inplace=True)
#sd
sd.head(5)
# Out:
#    Student ID  gender race/ethnicity parental level of education  \
# 0           1  female        group B           bachelor's degree
# 1           2  female        group C                     Diploma
# 2           3  female        group B             master's degree
# 3           4    male        group A          associate's degree
# 4           5    male        group C                     Diploma
#
#           lunch  Column  Column.1 test preparation course  math score  \
# 0      standard     NaN       NaN                    none        72.0
# 1      standard     NaN       NaN               completed        69.0
# 2      standard     NaN       NaN                    none        90.0
# 3  free/reduced     NaN       NaN                    none        47.0
# 4      standard     NaN       NaN                    none        76.0
#
#    reading score  writing score
# 0           72.0           74.0
# 1           90.0           88.0
# 2           95.0           93.0
# 3           57.0           44.0
# 4           78.0           75.0

# %%
#11. Find the total score of each student
sd1.groupby('Student ID').sum()['Total Score']
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\478177445.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd1.groupby('Student ID').sum()['Total Score']
# Student ID
# 1       218.0
# 2       247.0
# 3       278.0
# 4       148.0
# 5       229.0
#         ...
# 1001    282.0
# 1002    172.0
# 1003    195.0
# 1004    223.0
# 1005    249.0
# Name: Total Score, Length: 1005, dtype: float64

# %%
#12.What is the average of total score for male and female students?
total1_list=[66089.0,69169.0,68054.0]

sd.groupby('gender').sum(total1_list)
#sd.drop('Column.1',axis=1,inplace=True)
#sd
# Out:
#         Student ID  Column  Column.1  math score  reading score  writing score
# gender
# female      268503     0.0       0.0     32962.0        37611.0        37538.0
# male        237012     0.0       0.0     33127.0        31558.0        30516.0

# %%
#12.What is the average of total score for male and female students?
sd1.groupby('gender').mean()['Total Score']
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\2031592804.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd1.groupby('gender').mean()['Total Score']
# gender
# female    208.708494
# male      197.512448
# Name: Total Score, dtype: float64

# %%
#13.What is the average of total score by gender and parental education level?
#total2_list=[66089.0,69169.0,68054.0]
sd1.groupby(['gender','parental level of education']).sum()['Total Score']
#sd.drop('Column',axis=1,inplace=True)
#sd
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\2622692308.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd1.groupby(['gender','parental level of education']).sum()['Total Score']
# gender  parental level of education
# female  Diploma                        25135.0
#         associate's degree             24751.0
#         bachelor's degree              14113.0
#         high school                    36158.0
#         master's degree                 7954.0
# male    Diploma                        21292.0
#         associate's degree             21582.0
#         bachelor's degree              11348.0
#         high school                    35906.0
#         master's degree                 5073.0
# Name: Total Score, dtype: float64

# %%
#13.What is the average of total score by gender and parental education level?
sd1.groupby(['gender','parental level of education']).mean()['Total Score']
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\2899788497.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd1.groupby(['gender','parental level of education']).mean()['Total Score']
# gender  parental level of education
# female  Diploma                        213.008475
#         associate's degree             213.370690
#         bachelor's degree              224.015873
#         high school                    195.448649
#         master's degree                220.944444
# male    Diploma                        197.148148
#         associate's degree             203.603774
#         bachelor's degree              206.327273
#         high school                    188.978947
#         master's degree                220.565217
# Name: Total Score, dtype: float64

# %%
#14.What is the average math score by race/ethnicity?
sd1.groupby('race/ethnicity').mean()['math score']
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\4051283016.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd1.groupby('race/ethnicity').mean()['math score']
# race/ethnicity
# group A    61.629213
# group B    63.452632
# group C    64.463950
# group D    67.362595
# group E    73.821429
# Name: math score, dtype: float64

# %%
#15.Find the number of Students by test preparation course
sd1.groupby('test preparation course').count()['Student ID']
# Out:
# test preparation course
# completed    361
# none         644
# Name: Student ID, dtype: int64

# %%
#16. Find the average total score by test preparation course
sd1.groupby('test preparation course').mean()['Total Score']
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8304\1182840673.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd1.groupby('test preparation course').mean()['Total Score']
# test preparation course
# completed    218.008380
# none         195.116822
# Name: Total Score, dtype: float64

# %%
#17. create a new variable as, 'Score', and the values in the column should be the sum of all the three papers.

# %%
sd1['Score']=(sd1['math score']+sd1['reading score']+sd1['writing score'])/300*3
sd1
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# 1         standard               completed        69.0           90.0
# 2         standard                    none        90.0           95.0
# 3     free/reduced                    none        47.0           57.0
# 4         standard                    none        76.0           78.0
# ...            ...                     ...         ...            ...
# 1000      standard               completed        88.0           99.0
# 1001  free/reduced                    none        62.0           55.0
# 1002  free/reduced               completed        59.0           71.0
# 1003      standard               completed        68.0           78.0
# 1004  free/reduced                    none        77.0           86.0
#
#       writing score  Total Score  Score
# 0              74.0        218.0   2.18
# 1              88.0        247.0   2.47
# 2              93.0        278.0   2.78
# 3              44.0        148.0   1.48
# 4              75.0        229.0   2.29
# ...             ...          ...    ...
# 1000           95.0        282.0   2.82
# 1001           55.0        172.0   1.72
# 1002           65.0        195.0   1.95
# 1003           77.0        223.0   2.23
# 1004           86.0        249.0   2.49
#
# [1005 rows x 11 columns]

# %%
#18. create a new variable as, " Percentage", and find the percentage for the score 

sd1['Percentage']=(sd1['Total Score']/300*100)
sd1
#sd1.drop('Score',axis=1,inplace=True)
# Out:
#       Student ID  gender race/ethnicity parental level of education  \
# 0              1  female        group B           bachelor's degree
# 1              2  female        group C                     Diploma
# 2              3  female        group B             master's degree
# 3              4    male        group A          associate's degree
# 4              5    male        group C                     Diploma
# ...          ...     ...            ...                         ...
# 1000        1001  female        group E             master's degree
# 1001        1002    male        group C                 high school
# 1002        1003  female        group C                 high school
# 1003        1004  female        group D                     Diploma
# 1004        1005  female        group D                     Diploma
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none        72.0           72.0
# 1         standard               completed        69.0           90.0
# 2         standard                    none        90.0           95.0
# 3     free/reduced                    none        47.0           57.0
# 4         standard                    none        76.0           78.0
# ...            ...                     ...         ...            ...
# 1000      standard               completed        88.0           99.0
# 1001  free/reduced                    none        62.0           55.0
# 1002  free/reduced               completed        59.0           71.0
# 1003      standard               completed        68.0           78.0
# 1004  free/reduced                    none        77.0           86.0
#
#       writing score  Total Score  Percentage Status
# 0              74.0        218.0   72.666667   pass
# 1              88.0        247.0   82.333333   pass
# 2              93.0        278.0   92.666667   pass
# 3              44.0        148.0   49.333333   pass
# 4              75.0        229.0   76.333333   pass
# ...             ...          ...         ...    ...
# 1000           95.0        282.0   94.000000   pass
# 1001           55.0        172.0   57.333333   pass
# 1002           65.0        195.0   65.000000   pass
# 1003           77.0        223.0   74.333333   pass
# 1004           86.0        249.0   83.000000   pass
#
# [1005 rows x 12 columns]

# %%
#from math import * 

#sd1['Percentage'] = sd1['Total Score']/3

#for i in range(0, 1000):
    
 #sd1['Percentage'][i] = ceil(sd1['Percentage'][i])

#sd1['Percentage'].value_counts(normalize = True)
#sd1['Percentage'].value_counts(dropna = False).plot.bar(figsize = (16, 8), color = 'red')

#plt.title('Comparison of percentage scored by all the students')
#plt.xlabel('percentage score')
#plt.ylabel('count')
#plt.show()

# %%
#19. create a new variable called, 'status'. Inside this column, find the status as Pass \ Fail, those who score above 40 % will pass the exam
passmark=120
sd1['Status']=np.where(sd1['Total Score']>passmark,'pass','fail')
#sd1['reading status']=np.where(sd1['reading score']>passmark,'pass', 'fail')
#sd1['writing status']=np.where(sd1['writing score']>passmark,'pass','fail')
sd1
sd1.head(25)
#sd1.drop('Score',axis=1,inplace=True)
# Out:
#     Student ID  gender race/ethnicity parental level of education  \
# 0            1  female        group B           bachelor's degree
# 1            2  female        group C                     Diploma
# 2            3  female        group B             master's degree
# 3            4    male        group A          associate's degree
# 4            5    male        group C                     Diploma
# 5            6  female        group B          associate's degree
# 6            7  female        group B                     Diploma
# 7            8    male        group B                     Diploma
# 8            9    male        group D                 high school
# 9           10  female        group B                 high school
# 10          11    male        group C          associate's degree
# 11          12    male        group D          associate's degree
# 12          13  female        group B                 high school
# 13          14    male        group A                     Diploma
# 14          15  female        group A             master's degree
# 15          16  female        group C                 high school
# 16          17    male        group C                 high school
# 17          18  female        group B                 high school
# 18          19    male        group C             master's degree
# 19          20  female        group C          associate's degree
# 20          21    male        group D                 high school
# 21          22  female        group B                     Diploma
# 22          23    male        group D                     Diploma
# 23          24  female        group C                 high school
# 24          25    male        group D           bachelor's degree
#
#            lunch test preparation course  math score  reading score  \
# 0       standard                    none        72.0           72.0
# 1       standard               completed        69.0           90.0
# 2       standard                    none        90.0           95.0
# 3   free/reduced                    none        47.0           57.0
# 4       standard                    none        76.0           78.0
# 5       standard                    none        71.0           83.0
# 6       standard               completed        88.0           95.0
# 7   free/reduced                    none        40.0           43.0
# 8   free/reduced               completed        64.0           64.0
# 9   free/reduced                    none        38.0           60.0
# 10      standard                    none        58.0           54.0
# 11      standard                    none        40.0           52.0
# 12      standard                    none        65.0           81.0
# 13      standard               completed        78.0           72.0
# 14      standard                    none        50.0           53.0
# 15      standard                    none        69.0           75.0
# 16      standard                    none        88.0           89.0
# 17  free/reduced                    none        18.0           32.0
# 18  free/reduced               completed        46.0           42.0
# 19  free/reduced                    none        54.0           58.0
# 20      standard                    none        66.0           69.0
# 21  free/reduced               completed        65.0           75.0
# 22      standard                    none        44.0           54.0
# 23      standard                    none        69.0           73.0
# 24  free/reduced               completed        74.0           71.0
#
#     writing score  Total Score  Percentage Status
# 0            74.0        218.0   72.666667   pass
# 1            88.0        247.0   82.333333   pass
# 2            93.0        278.0   92.666667   pass
# 3            44.0        148.0   49.333333   pass
# 4            75.0        229.0   76.333333   pass
# 5            78.0        232.0   77.333333   pass
# 6            92.0        275.0   91.666667   pass
# 7            39.0        122.0   40.666667   pass
# 8            67.0        195.0   65.000000   pass
# 9            50.0        148.0   49.333333   pass
# 10           52.0        164.0   54.666667   pass
# 11           43.0        135.0   45.000000   pass
# 12           73.0        219.0   73.000000   pass
# 13           70.0        220.0   73.333333   pass
# 14           58.0        161.0   53.666667   pass
# 15           78.0        222.0   74.000000   pass
# 16           86.0        263.0   87.666667   pass
# 17           28.0         78.0   26.000000   fail
# 18           46.0        134.0   44.666667   pass
# 19           61.0        173.0   57.666667   pass
# 20           63.0        198.0   66.000000   pass
# 21           70.0        210.0   70.000000   pass
# 22           53.0        151.0   50.333333   pass
# 23           73.0        215.0   71.666667   pass
# 24           80.0        225.0   75.000000   pass

# %%
#20. create a pie chart using the status column
sd1['Status'].value_counts().plot(kind='pie',autopct='%1.2f%%')
sd1
plt.title('Status')
# Out:
# Text(0.5, 1.0, 'Status')
